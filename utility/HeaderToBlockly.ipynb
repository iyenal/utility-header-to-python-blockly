# %%
# Gen7 Engine Python3 utility to convert a C/C++ header to a Blockly toolkit
    
import re

# initializing string

txt = open("header-list.h", "r").read()

txt = txt.replace("}", "} ;")
txt = txt.replace("//{", "")
txt = txt.replace("){", " ) ")
txt = re.sub('{[^}]+}', '', txt)
txt = txt.replace("(", " ")
txt = txt.replace(")", " ")
txt = txt.replace(",", " ")
txt = txt.replace("char *", "str ")
txt = txt.replace("char*", "str")
txt = txt.replace("static ", "")

    
# printing original string 
print ("-----------The original signature : \n" +  txt) 
    
# using split() 
# to extract words from string 
res = txt.split()

function_typedef = ""
function_name = ""
function_param = []
function_types = []

_fname = 0
_ftype = 0
_fparam = 0

output = ""
xml = ""

def reset_blocks_line():
    global function_typedef
    global function_name
    global function_param
    global function_types
    
    function_typedef = ""
    function_name = ""
    function_param = []
    function_types = []
    _fname = 0
    _ftype = 0
    _fparam = 0

def generate_blocks_line():
    global output
    global xml
    global function_typedef
    global function_name
    global function_param
    global function_types
    
    print(function_name)
    print(function_param)
    print(function_types)

    
    """
    Blockly.Blocks['createObjectWithRotationScale'] = { init: function() { this.appendDummyInput().appendField("createObjectWithRotationScale");

    this.appendValueInput('posX').setCheck('Number').appendField('posX');
    this.appendValueInput("posY").setCheck("Number").appendField("posY");
    this.appendValueInput("filename").setCheck("String").appendField("Filename");

    this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip("");this.setHelpUrl("");}};
    """
    
    # -------------------- Blockly Block
    
    # Function declaration
    blocks_line = "Blockly.Blocks['"+function_name+"'] = { init: function() { this.appendDummyInput().appendField('"+function_name+"');\n"
    
    # Function Body
    for i in range(0, len(function_param)):
        
        # Number
        if(function_types[i] == "int" or function_types[i] == "float"):
            blocks_line += "\tthis.appendValueInput('"+function_param[i]+"').setCheck('Number').appendField('"+function_param[i]+"');\n"
        # String
        if(function_types[i] == "str"):
            blocks_line += "\tthis.appendValueInput('"+function_param[i]+"').setCheck('String').appendField('"+function_param[i]+"');\n"
      
    # Function end
    if(len(function_param) > 0):
        blocks_line+="this.appendDummyInput();"
        
    if(function_typedef == "bool"):
        blocks_line+="this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};\n"
    elif(function_typedef == "str"):
        blocks_line+="this.setOutput(true, 'String');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};\n"
    elif(function_typedef == "float"):
        blocks_line+="this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};\n"
    elif(function_typedef == "int"):
        blocks_line+="this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};\n"
    elif(function_typedef == "void"):
        blocks_line+="this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};\n"
    blocks_line+="\n"
    
    # ------------------- Blockly Generator
    
    """
    Blockly.Python['createObjectWithRotationScale'] = function(block) {

      var posX = Blockly.Python.valueToCode(block, 'posX', Blockly.Python.ORDER_ATOMIC);
      var posY = Blockly.Python.valueToCode(block, 'posY', Blockly.Python.ORDER_ATOMIC);
      var filename = Blockly.Python.valueToCode(block, 'filename', Blockly.Python.ORDER_ATOMIC);

      var code = 'createObjectWithRotationScale('+posX+','+posY+','+filename+')\n';

    return code;};
    """
    
    # Function declaration
    blocks_line += "Blockly.Python['"+function_name+"'] = function(block) {\n"
    
    # Function Body
    for i in range(0, len(function_param)):
        
        blocks_line += "\tvar "+function_param[i]+" = Blockly.Python.valueToCode(block, '"+function_param[i]+"', Blockly.Python.ORDER_ATOMIC);\n"
      
    # Function end
    blocks_line+="\n\tvar code = '"+function_name+"("
    for i in range(0, len(function_param)):
        
        if(i != 0):
            blocks_line += "+','+"
        else:
            blocks_line += "'+"
            
        blocks_line += function_param[i]
        
        if(i == len(function_param)-1):
            blocks_line += "+'"
            
    if(function_typedef == "void"):
        blocks_line+=")\\n';"
        blocks_line+="\nreturn code;};"
    else:
        blocks_line+=")';"
        blocks_line+="\nreturn [code, Blockly.Python.ORDER_NONE];};"
    blocks_line+="\n"
    
    # ------- Add everything
    
    output+=blocks_line
    xml+='\t<block type="'+function_name+'"></block>\n'
    
    print(blocks_line)
    
# printing result 
print ("\n---------The words :")

for i in res:
    
    #print(i)
    
    # Reset new method
    if(i == ";"):
        print("----New method----")
        generate_blocks_line()
        reset_blocks_line()
        _fname = 0
        continue
        
    # Get function signature type
    if(_fname == 0):
        function_typedef = i
        _fname = 1
        continue
    # Get function signature name
    if(_fname == 1):
        function_name = i
        _fname = 2
        continue
        
    # Get function param type
    if(_ftype == 0):
        function_types.append(i)
        _ftype = 1
        _fparam = 1
        continue
        
    # Get function param name
    if(_fparam == 1):
        function_param.append(i)
        _ftype = 0
        _fparam = 0
        continue
    
    
print("\n")
print("\n")
print("\n")
print("============================================= EXPORTED ====================================================")
print("\n")
print("BLOCKLY JS:\n")
print("\n")
print(output)
print("\n")
print("BLOCKLY XML:\n")
print("\n")
print(xml)
# Out:
# -----------The original signature :
# float timeSinceFrameMs  ;
# bool isButtonRight  ;
# bool isButtonLeft  ;
# bool isButtonDown  ;
# bool isButtonUp  ;
# bool isButtonY  ;
# bool isButtonX  ;
# bool isButtonB  ;
# bool isButtonA  ;
# void enableObject str name ;
# void disableObject str name ;
# void createLog str text ;
# void cleanLog  ;
# void createText int xpos int ypos int r int g int b float fontsize str text ;
# void updateSprite str name str asset ;
# void moveSprite str name float x float y int layer ;
# void setSprite str name float x float y float sizeX float sizeY int layer ;
# void deleteObject str name ;
# void deleteSpritefontText str name ;
# void createSpritefontText str name int xpos int ypos int fontsize float condens int lines int columns str text str fontface str spritefont ;
# void createSpriteWithCoords str name str asset float x float y float sizeX float sizeY float t0 float t1 float t2 float t3 int layer ;
# void createSpriteWithColor str name str asset float x float y float sizeX float sizeY int r int g int b int layer ;
# void createSprite str name str asset float x float y float sizeX float sizeY int layer ;
# float getObjectSZ str name ;
# float getObjectSY str name ;
# float getObjectSX str name ;
# float getObjectRZ str name ;
# float getObjectRY str name ;
# float getObjectRX str name ;
# float getObjectPZ str name ;
# float getObjectPY str name ;
# float getObjectPX str name ;
# void setObjectwithRotationScale str name float x float y float z float rotX float rotY float rotZ float scX float scY float scZ ;
# void moveObjectwithRotationScale str name float x float y float z float rotX float rotY float rotZ float scX float scY float scZ ;
# void setObject str name float x float y float z ;
# void createObjectwithRotationScale str name str asset float x float y float z float rotX float rotY float rotZ float scX float scY float scZ ;
# void createObjectwithScale str name str asset float x float y float z float scX float scY float scZ ;
# void createObjectwithRotation str name str asset float x float y float z float rotX float rotY float rotZ ;
# void createObject str name str asset float x float y float z ;
# void writeFile str filename str text ;
# str openFile str filename ;
# int timeSinceStartup  ;
# str getPlatform  ;
# void enableRenderWireframe  ;
# void enableRenderSolid  ;
# void enableRenderTexture  ;
# void enableRenderShaded  ;
# void moveCamera float x float y float z float rx float ry float rz ;
# void setCamera float x float y float z float rx float ry float rz ;
# void createAssetSkybox str s1 str s2 str s3 str s4 str s5 str s6 ;
# void createAssetPlane str name ;
# void createAssetTeapot str name ;
# void createAssetCone str name ;
# void createAssetTorus str name ;
# void createAssetSphere str name ;
# void createAssetCube str name ;
# void createAssetModel str name str filename ;
# void createAssetParticle str name str filename int ParticleCount int FrameCount float scaleParticle ;
# void createAssetTexture str name str filename ;
#
#
# ---------The words :
# ----New method----
# timeSinceFrameMs
# []
# []
# Blockly.Blocks['timeSinceFrameMs'] = { init: function() { this.appendDummyInput().appendField('timeSinceFrameMs');
# this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['timeSinceFrameMs'] = function(block) {
#
# 	var code = 'timeSinceFrameMs()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# isButtonRight
# []
# []
# Blockly.Blocks['isButtonRight'] = { init: function() { this.appendDummyInput().appendField('isButtonRight');
# this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['isButtonRight'] = function(block) {
#
# 	var code = 'isButtonRight()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# isButtonLeft
# []
# []
# Blockly.Blocks['isButtonLeft'] = { init: function() { this.appendDummyInput().appendField('isButtonLeft');
# this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['isButtonLeft'] = function(block) {
#
# 	var code = 'isButtonLeft()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# isButtonDown
# []
# []
# Blockly.Blocks['isButtonDown'] = { init: function() { this.appendDummyInput().appendField('isButtonDown');
# this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['isButtonDown'] = function(block) {
#
# 	var code = 'isButtonDown()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# isButtonUp
# []
# []
# Blockly.Blocks['isButtonUp'] = { init: function() { this.appendDummyInput().appendField('isButtonUp');
# this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['isButtonUp'] = function(block) {
#
# 	var code = 'isButtonUp()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# isButtonY
# []
# []
# Blockly.Blocks['isButtonY'] = { init: function() { this.appendDummyInput().appendField('isButtonY');
# this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['isButtonY'] = function(block) {
#
# 	var code = 'isButtonY()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# isButtonX
# []
# []
# Blockly.Blocks['isButtonX'] = { init: function() { this.appendDummyInput().appendField('isButtonX');
# this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['isButtonX'] = function(block) {
#
# 	var code = 'isButtonX()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# isButtonB
# []
# []
# Blockly.Blocks['isButtonB'] = { init: function() { this.appendDummyInput().appendField('isButtonB');
# this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['isButtonB'] = function(block) {
#
# 	var code = 'isButtonB()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# isButtonA
# []
# []
# Blockly.Blocks['isButtonA'] = { init: function() { this.appendDummyInput().appendField('isButtonA');
# this.setOutput(true, 'Boolean');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['isButtonA'] = function(block) {
#
# 	var code = 'isButtonA()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# enableObject
# ['name']
# ['str']
# Blockly.Blocks['enableObject'] = { init: function() { this.appendDummyInput().appendField('enableObject');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableObject'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'enableObject('+name+')\n';
# return code;};
#
# ----New method----
# disableObject
# ['name']
# ['str']
# Blockly.Blocks['disableObject'] = { init: function() { this.appendDummyInput().appendField('disableObject');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['disableObject'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'disableObject('+name+')\n';
# return code;};
#
# ----New method----
# createLog
# ['text']
# ['str']
# Blockly.Blocks['createLog'] = { init: function() { this.appendDummyInput().appendField('createLog');
# 	this.appendValueInput('text').setCheck('String').appendField('text');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createLog'] = function(block) {
# 	var text = Blockly.Python.valueToCode(block, 'text', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createLog('+text+')\n';
# return code;};
#
# ----New method----
# cleanLog
# []
# []
# Blockly.Blocks['cleanLog'] = { init: function() { this.appendDummyInput().appendField('cleanLog');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['cleanLog'] = function(block) {
#
# 	var code = 'cleanLog()\n';
# return code;};
#
# ----New method----
# createText
# ['xpos', 'ypos', 'r', 'g', 'b', 'fontsize', 'text']
# ['int', 'int', 'int', 'int', 'int', 'float', 'str']
# Blockly.Blocks['createText'] = { init: function() { this.appendDummyInput().appendField('createText');
# 	this.appendValueInput('xpos').setCheck('Number').appendField('xpos');
# 	this.appendValueInput('ypos').setCheck('Number').appendField('ypos');
# 	this.appendValueInput('r').setCheck('Number').appendField('r');
# 	this.appendValueInput('g').setCheck('Number').appendField('g');
# 	this.appendValueInput('b').setCheck('Number').appendField('b');
# 	this.appendValueInput('fontsize').setCheck('Number').appendField('fontsize');
# 	this.appendValueInput('text').setCheck('String').appendField('text');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createText'] = function(block) {
# 	var xpos = Blockly.Python.valueToCode(block, 'xpos', Blockly.Python.ORDER_ATOMIC);
# 	var ypos = Blockly.Python.valueToCode(block, 'ypos', Blockly.Python.ORDER_ATOMIC);
# 	var r = Blockly.Python.valueToCode(block, 'r', Blockly.Python.ORDER_ATOMIC);
# 	var g = Blockly.Python.valueToCode(block, 'g', Blockly.Python.ORDER_ATOMIC);
# 	var b = Blockly.Python.valueToCode(block, 'b', Blockly.Python.ORDER_ATOMIC);
# 	var fontsize = Blockly.Python.valueToCode(block, 'fontsize', Blockly.Python.ORDER_ATOMIC);
# 	var text = Blockly.Python.valueToCode(block, 'text', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createText('+xpos+','+ypos+','+r+','+g+','+b+','+fontsize+','+text+')\n';
# return code;};
#
# ----New method----
# updateSprite
# ['name', 'asset']
# ['str', 'str']
# Blockly.Blocks['updateSprite'] = { init: function() { this.appendDummyInput().appendField('updateSprite');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('asset').setCheck('String').appendField('asset');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['updateSprite'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var asset = Blockly.Python.valueToCode(block, 'asset', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'updateSprite('+name+','+asset+')\n';
# return code;};
#
# ----New method----
# moveSprite
# ['name', 'x', 'y', 'layer']
# ['str', 'float', 'float', 'int']
# Blockly.Blocks['moveSprite'] = { init: function() { this.appendDummyInput().appendField('moveSprite');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('layer').setCheck('Number').appendField('layer');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['moveSprite'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var layer = Blockly.Python.valueToCode(block, 'layer', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'moveSprite('+name+','+x+','+y+','+layer+')\n';
# return code;};
#
# ----New method----
# setSprite
# ['name', 'x', 'y', 'sizeX', 'sizeY', 'layer']
# ['str', 'float', 'float', 'float', 'float', 'int']
# Blockly.Blocks['setSprite'] = { init: function() { this.appendDummyInput().appendField('setSprite');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('sizeX').setCheck('Number').appendField('sizeX');
# 	this.appendValueInput('sizeY').setCheck('Number').appendField('sizeY');
# 	this.appendValueInput('layer').setCheck('Number').appendField('layer');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['setSprite'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var sizeX = Blockly.Python.valueToCode(block, 'sizeX', Blockly.Python.ORDER_ATOMIC);
# 	var sizeY = Blockly.Python.valueToCode(block, 'sizeY', Blockly.Python.ORDER_ATOMIC);
# 	var layer = Blockly.Python.valueToCode(block, 'layer', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'setSprite('+name+','+x+','+y+','+sizeX+','+sizeY+','+layer+')\n';
# return code;};
#
# ----New method----
# deleteObject
# ['name']
# ['str']
# Blockly.Blocks['deleteObject'] = { init: function() { this.appendDummyInput().appendField('deleteObject');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['deleteObject'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'deleteObject('+name+')\n';
# return code;};
#
# ----New method----
# deleteSpritefontText
# ['name']
# ['str']
# Blockly.Blocks['deleteSpritefontText'] = { init: function() { this.appendDummyInput().appendField('deleteSpritefontText');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['deleteSpritefontText'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'deleteSpritefontText('+name+')\n';
# return code;};
#
# ----New method----
# createSpritefontText
# ['name', 'xpos', 'ypos', 'fontsize', 'condens', 'lines', 'columns', 'text', 'fontface', 'spritefont']
# ['str', 'int', 'int', 'int', 'float', 'int', 'int', 'str', 'str', 'str']
# Blockly.Blocks['createSpritefontText'] = { init: function() { this.appendDummyInput().appendField('createSpritefontText');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('xpos').setCheck('Number').appendField('xpos');
# 	this.appendValueInput('ypos').setCheck('Number').appendField('ypos');
# 	this.appendValueInput('fontsize').setCheck('Number').appendField('fontsize');
# 	this.appendValueInput('condens').setCheck('Number').appendField('condens');
# 	this.appendValueInput('lines').setCheck('Number').appendField('lines');
# 	this.appendValueInput('columns').setCheck('Number').appendField('columns');
# 	this.appendValueInput('text').setCheck('String').appendField('text');
# 	this.appendValueInput('fontface').setCheck('String').appendField('fontface');
# 	this.appendValueInput('spritefont').setCheck('String').appendField('spritefont');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createSpritefontText'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var xpos = Blockly.Python.valueToCode(block, 'xpos', Blockly.Python.ORDER_ATOMIC);
# 	var ypos = Blockly.Python.valueToCode(block, 'ypos', Blockly.Python.ORDER_ATOMIC);
# 	var fontsize = Blockly.Python.valueToCode(block, 'fontsize', Blockly.Python.ORDER_ATOMIC);
# 	var condens = Blockly.Python.valueToCode(block, 'condens', Blockly.Python.ORDER_ATOMIC);
# 	var lines = Blockly.Python.valueToCode(block, 'lines', Blockly.Python.ORDER_ATOMIC);
# 	var columns = Blockly.Python.valueToCode(block, 'columns', Blockly.Python.ORDER_ATOMIC);
# 	var text = Blockly.Python.valueToCode(block, 'text', Blockly.Python.ORDER_ATOMIC);
# 	var fontface = Blockly.Python.valueToCode(block, 'fontface', Blockly.Python.ORDER_ATOMIC);
# 	var spritefont = Blockly.Python.valueToCode(block, 'spritefont', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createSpritefontText('+name+','+xpos+','+ypos+','+fontsize+','+condens+','+lines+','+columns+','+text+','+fontface+','+spritefont+')\n';
# return code;};
#
# ----New method----
# createSpriteWithCoords
# ['name', 'asset', 'x', 'y', 'sizeX', 'sizeY', 't0', 't1', 't2', 't3', 'layer']
# ['str', 'str', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'int']
# Blockly.Blocks['createSpriteWithCoords'] = { init: function() { this.appendDummyInput().appendField('createSpriteWithCoords');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('asset').setCheck('String').appendField('asset');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('sizeX').setCheck('Number').appendField('sizeX');
# 	this.appendValueInput('sizeY').setCheck('Number').appendField('sizeY');
# 	this.appendValueInput('t0').setCheck('Number').appendField('t0');
# 	this.appendValueInput('t1').setCheck('Number').appendField('t1');
# 	this.appendValueInput('t2').setCheck('Number').appendField('t2');
# 	this.appendValueInput('t3').setCheck('Number').appendField('t3');
# 	this.appendValueInput('layer').setCheck('Number').appendField('layer');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createSpriteWithCoords'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var asset = Blockly.Python.valueToCode(block, 'asset', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var sizeX = Blockly.Python.valueToCode(block, 'sizeX', Blockly.Python.ORDER_ATOMIC);
# 	var sizeY = Blockly.Python.valueToCode(block, 'sizeY', Blockly.Python.ORDER_ATOMIC);
# 	var t0 = Blockly.Python.valueToCode(block, 't0', Blockly.Python.ORDER_ATOMIC);
# 	var t1 = Blockly.Python.valueToCode(block, 't1', Blockly.Python.ORDER_ATOMIC);
# 	var t2 = Blockly.Python.valueToCode(block, 't2', Blockly.Python.ORDER_ATOMIC);
# 	var t3 = Blockly.Python.valueToCode(block, 't3', Blockly.Python.ORDER_ATOMIC);
# 	var layer = Blockly.Python.valueToCode(block, 'layer', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createSpriteWithCoords('+name+','+asset+','+x+','+y+','+sizeX+','+sizeY+','+t0+','+t1+','+t2+','+t3+','+layer+')\n';
# return code;};
#
# ----New method----
# createSpriteWithColor
# ['name', 'asset', 'x', 'y', 'sizeX', 'sizeY', 'r', 'g', 'b', 'layer']
# ['str', 'str', 'float', 'float', 'float', 'float', 'int', 'int', 'int', 'int']
# Blockly.Blocks['createSpriteWithColor'] = { init: function() { this.appendDummyInput().appendField('createSpriteWithColor');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('asset').setCheck('String').appendField('asset');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('sizeX').setCheck('Number').appendField('sizeX');
# 	this.appendValueInput('sizeY').setCheck('Number').appendField('sizeY');
# 	this.appendValueInput('r').setCheck('Number').appendField('r');
# 	this.appendValueInput('g').setCheck('Number').appendField('g');
# 	this.appendValueInput('b').setCheck('Number').appendField('b');
# 	this.appendValueInput('layer').setCheck('Number').appendField('layer');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createSpriteWithColor'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var asset = Blockly.Python.valueToCode(block, 'asset', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var sizeX = Blockly.Python.valueToCode(block, 'sizeX', Blockly.Python.ORDER_ATOMIC);
# 	var sizeY = Blockly.Python.valueToCode(block, 'sizeY', Blockly.Python.ORDER_ATOMIC);
# 	var r = Blockly.Python.valueToCode(block, 'r', Blockly.Python.ORDER_ATOMIC);
# 	var g = Blockly.Python.valueToCode(block, 'g', Blockly.Python.ORDER_ATOMIC);
# 	var b = Blockly.Python.valueToCode(block, 'b', Blockly.Python.ORDER_ATOMIC);
# 	var layer = Blockly.Python.valueToCode(block, 'layer', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createSpriteWithColor('+name+','+asset+','+x+','+y+','+sizeX+','+sizeY+','+r+','+g+','+b+','+layer+')\n';
# return code;};
#
# ----New method----
# createSprite
# ['name', 'asset', 'x', 'y', 'sizeX', 'sizeY', 'layer']
# ['str', 'str', 'float', 'float', 'float', 'float', 'int']
# Blockly.Blocks['createSprite'] = { init: function() { this.appendDummyInput().appendField('createSprite');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('asset').setCheck('String').appendField('asset');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('sizeX').setCheck('Number').appendField('sizeX');
# 	this.appendValueInput('sizeY').setCheck('Number').appendField('sizeY');
# 	this.appendValueInput('layer').setCheck('Number').appendField('layer');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createSprite'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var asset = Blockly.Python.valueToCode(block, 'asset', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var sizeX = Blockly.Python.valueToCode(block, 'sizeX', Blockly.Python.ORDER_ATOMIC);
# 	var sizeY = Blockly.Python.valueToCode(block, 'sizeY', Blockly.Python.ORDER_ATOMIC);
# 	var layer = Blockly.Python.valueToCode(block, 'layer', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createSprite('+name+','+asset+','+x+','+y+','+sizeX+','+sizeY+','+layer+')\n';
# return code;};
#
# ----New method----
# getObjectSZ
# ['name']
# ['str']
# Blockly.Blocks['getObjectSZ'] = { init: function() { this.appendDummyInput().appendField('getObjectSZ');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectSZ'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectSZ('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getObjectSY
# ['name']
# ['str']
# Blockly.Blocks['getObjectSY'] = { init: function() { this.appendDummyInput().appendField('getObjectSY');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectSY'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectSY('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getObjectSX
# ['name']
# ['str']
# Blockly.Blocks['getObjectSX'] = { init: function() { this.appendDummyInput().appendField('getObjectSX');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectSX'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectSX('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getObjectRZ
# ['name']
# ['str']
# Blockly.Blocks['getObjectRZ'] = { init: function() { this.appendDummyInput().appendField('getObjectRZ');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectRZ'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectRZ('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getObjectRY
# ['name']
# ['str']
# Blockly.Blocks['getObjectRY'] = { init: function() { this.appendDummyInput().appendField('getObjectRY');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectRY'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectRY('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getObjectRX
# ['name']
# ['str']
# Blockly.Blocks['getObjectRX'] = { init: function() { this.appendDummyInput().appendField('getObjectRX');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectRX'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectRX('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getObjectPZ
# ['name']
# ['str']
# Blockly.Blocks['getObjectPZ'] = { init: function() { this.appendDummyInput().appendField('getObjectPZ');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectPZ'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectPZ('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getObjectPY
# ['name']
# ['str']
# Blockly.Blocks['getObjectPY'] = { init: function() { this.appendDummyInput().appendField('getObjectPY');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectPY'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectPY('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getObjectPX
# ['name']
# ['str']
# Blockly.Blocks['getObjectPX'] = { init: function() { this.appendDummyInput().appendField('getObjectPX');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getObjectPX'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'getObjectPX('+name+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# setObjectwithRotationScale
# ['name', 'x', 'y', 'z', 'rotX', 'rotY', 'rotZ', 'scX', 'scY', 'scZ']
# ['str', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float']
# Blockly.Blocks['setObjectwithRotationScale'] = { init: function() { this.appendDummyInput().appendField('setObjectwithRotationScale');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('rotX').setCheck('Number').appendField('rotX');
# 	this.appendValueInput('rotY').setCheck('Number').appendField('rotY');
# 	this.appendValueInput('rotZ').setCheck('Number').appendField('rotZ');
# 	this.appendValueInput('scX').setCheck('Number').appendField('scX');
# 	this.appendValueInput('scY').setCheck('Number').appendField('scY');
# 	this.appendValueInput('scZ').setCheck('Number').appendField('scZ');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['setObjectwithRotationScale'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var rotX = Blockly.Python.valueToCode(block, 'rotX', Blockly.Python.ORDER_ATOMIC);
# 	var rotY = Blockly.Python.valueToCode(block, 'rotY', Blockly.Python.ORDER_ATOMIC);
# 	var rotZ = Blockly.Python.valueToCode(block, 'rotZ', Blockly.Python.ORDER_ATOMIC);
# 	var scX = Blockly.Python.valueToCode(block, 'scX', Blockly.Python.ORDER_ATOMIC);
# 	var scY = Blockly.Python.valueToCode(block, 'scY', Blockly.Python.ORDER_ATOMIC);
# 	var scZ = Blockly.Python.valueToCode(block, 'scZ', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'setObjectwithRotationScale('+name+','+x+','+y+','+z+','+rotX+','+rotY+','+rotZ+','+scX+','+scY+','+scZ+')\n';
# return code;};
#
# ----New method----
# moveObjectwithRotationScale
# ['name', 'x', 'y', 'z', 'rotX', 'rotY', 'rotZ', 'scX', 'scY', 'scZ']
# ['str', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float']
# Blockly.Blocks['moveObjectwithRotationScale'] = { init: function() { this.appendDummyInput().appendField('moveObjectwithRotationScale');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('rotX').setCheck('Number').appendField('rotX');
# 	this.appendValueInput('rotY').setCheck('Number').appendField('rotY');
# 	this.appendValueInput('rotZ').setCheck('Number').appendField('rotZ');
# 	this.appendValueInput('scX').setCheck('Number').appendField('scX');
# 	this.appendValueInput('scY').setCheck('Number').appendField('scY');
# 	this.appendValueInput('scZ').setCheck('Number').appendField('scZ');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['moveObjectwithRotationScale'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var rotX = Blockly.Python.valueToCode(block, 'rotX', Blockly.Python.ORDER_ATOMIC);
# 	var rotY = Blockly.Python.valueToCode(block, 'rotY', Blockly.Python.ORDER_ATOMIC);
# 	var rotZ = Blockly.Python.valueToCode(block, 'rotZ', Blockly.Python.ORDER_ATOMIC);
# 	var scX = Blockly.Python.valueToCode(block, 'scX', Blockly.Python.ORDER_ATOMIC);
# 	var scY = Blockly.Python.valueToCode(block, 'scY', Blockly.Python.ORDER_ATOMIC);
# 	var scZ = Blockly.Python.valueToCode(block, 'scZ', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'moveObjectwithRotationScale('+name+','+x+','+y+','+z+','+rotX+','+rotY+','+rotZ+','+scX+','+scY+','+scZ+')\n';
# return code;};
#
# ----New method----
# setObject
# ['name', 'x', 'y', 'z']
# ['str', 'float', 'float', 'float']
# Blockly.Blocks['setObject'] = { init: function() { this.appendDummyInput().appendField('setObject');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['setObject'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'setObject('+name+','+x+','+y+','+z+')\n';
# return code;};
#
# ----New method----
# createObjectwithRotationScale
# ['name', 'asset', 'x', 'y', 'z', 'rotX', 'rotY', 'rotZ', 'scX', 'scY', 'scZ']
# ['str', 'str', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float']
# Blockly.Blocks['createObjectwithRotationScale'] = { init: function() { this.appendDummyInput().appendField('createObjectwithRotationScale');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('asset').setCheck('String').appendField('asset');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('rotX').setCheck('Number').appendField('rotX');
# 	this.appendValueInput('rotY').setCheck('Number').appendField('rotY');
# 	this.appendValueInput('rotZ').setCheck('Number').appendField('rotZ');
# 	this.appendValueInput('scX').setCheck('Number').appendField('scX');
# 	this.appendValueInput('scY').setCheck('Number').appendField('scY');
# 	this.appendValueInput('scZ').setCheck('Number').appendField('scZ');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createObjectwithRotationScale'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var asset = Blockly.Python.valueToCode(block, 'asset', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var rotX = Blockly.Python.valueToCode(block, 'rotX', Blockly.Python.ORDER_ATOMIC);
# 	var rotY = Blockly.Python.valueToCode(block, 'rotY', Blockly.Python.ORDER_ATOMIC);
# 	var rotZ = Blockly.Python.valueToCode(block, 'rotZ', Blockly.Python.ORDER_ATOMIC);
# 	var scX = Blockly.Python.valueToCode(block, 'scX', Blockly.Python.ORDER_ATOMIC);
# 	var scY = Blockly.Python.valueToCode(block, 'scY', Blockly.Python.ORDER_ATOMIC);
# 	var scZ = Blockly.Python.valueToCode(block, 'scZ', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createObjectwithRotationScale('+name+','+asset+','+x+','+y+','+z+','+rotX+','+rotY+','+rotZ+','+scX+','+scY+','+scZ+')\n';
# return code;};
#
# ----New method----
# createObjectwithScale
# ['name', 'asset', 'x', 'y', 'z', 'scX', 'scY', 'scZ']
# ['str', 'str', 'float', 'float', 'float', 'float', 'float', 'float']
# Blockly.Blocks['createObjectwithScale'] = { init: function() { this.appendDummyInput().appendField('createObjectwithScale');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('asset').setCheck('String').appendField('asset');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('scX').setCheck('Number').appendField('scX');
# 	this.appendValueInput('scY').setCheck('Number').appendField('scY');
# 	this.appendValueInput('scZ').setCheck('Number').appendField('scZ');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createObjectwithScale'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var asset = Blockly.Python.valueToCode(block, 'asset', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var scX = Blockly.Python.valueToCode(block, 'scX', Blockly.Python.ORDER_ATOMIC);
# 	var scY = Blockly.Python.valueToCode(block, 'scY', Blockly.Python.ORDER_ATOMIC);
# 	var scZ = Blockly.Python.valueToCode(block, 'scZ', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createObjectwithScale('+name+','+asset+','+x+','+y+','+z+','+scX+','+scY+','+scZ+')\n';
# return code;};
#
# ----New method----
# createObjectwithRotation
# ['name', 'asset', 'x', 'y', 'z', 'rotX', 'rotY', 'rotZ']
# ['str', 'str', 'float', 'float', 'float', 'float', 'float', 'float']
# Blockly.Blocks['createObjectwithRotation'] = { init: function() { this.appendDummyInput().appendField('createObjectwithRotation');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('asset').setCheck('String').appendField('asset');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('rotX').setCheck('Number').appendField('rotX');
# 	this.appendValueInput('rotY').setCheck('Number').appendField('rotY');
# 	this.appendValueInput('rotZ').setCheck('Number').appendField('rotZ');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createObjectwithRotation'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var asset = Blockly.Python.valueToCode(block, 'asset', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var rotX = Blockly.Python.valueToCode(block, 'rotX', Blockly.Python.ORDER_ATOMIC);
# 	var rotY = Blockly.Python.valueToCode(block, 'rotY', Blockly.Python.ORDER_ATOMIC);
# 	var rotZ = Blockly.Python.valueToCode(block, 'rotZ', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createObjectwithRotation('+name+','+asset+','+x+','+y+','+z+','+rotX+','+rotY+','+rotZ+')\n';
# return code;};
#
# ----New method----
# createObject
# ['name', 'asset', 'x', 'y', 'z']
# ['str', 'str', 'float', 'float', 'float']
# Blockly.Blocks['createObject'] = { init: function() { this.appendDummyInput().appendField('createObject');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('asset').setCheck('String').appendField('asset');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createObject'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var asset = Blockly.Python.valueToCode(block, 'asset', Blockly.Python.ORDER_ATOMIC);
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createObject('+name+','+asset+','+x+','+y+','+z+')\n';
# return code;};
#
# ----New method----
# writeFile
# ['filename', 'text']
# ['str', 'str']
# Blockly.Blocks['writeFile'] = { init: function() { this.appendDummyInput().appendField('writeFile');
# 	this.appendValueInput('filename').setCheck('String').appendField('filename');
# 	this.appendValueInput('text').setCheck('String').appendField('text');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['writeFile'] = function(block) {
# 	var filename = Blockly.Python.valueToCode(block, 'filename', Blockly.Python.ORDER_ATOMIC);
# 	var text = Blockly.Python.valueToCode(block, 'text', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'writeFile('+filename+','+text+')\n';
# return code;};
#
# ----New method----
# openFile
# ['filename']
# ['str']
# Blockly.Blocks['openFile'] = { init: function() { this.appendDummyInput().appendField('openFile');
# 	this.appendValueInput('filename').setCheck('String').appendField('filename');
# this.appendDummyInput();this.setOutput(true, 'String');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['openFile'] = function(block) {
# 	var filename = Blockly.Python.valueToCode(block, 'filename', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'openFile('+filename+')';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# timeSinceStartup
# []
# []
# Blockly.Blocks['timeSinceStartup'] = { init: function() { this.appendDummyInput().appendField('timeSinceStartup');
# this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['timeSinceStartup'] = function(block) {
#
# 	var code = 'timeSinceStartup()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# getPlatform
# []
# []
# Blockly.Blocks['getPlatform'] = { init: function() { this.appendDummyInput().appendField('getPlatform');
# this.setOutput(true, 'String');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getPlatform'] = function(block) {
#
# 	var code = 'getPlatform()';
# return [code, Blockly.Python.ORDER_NONE];};
#
# ----New method----
# enableRenderWireframe
# []
# []
# Blockly.Blocks['enableRenderWireframe'] = { init: function() { this.appendDummyInput().appendField('enableRenderWireframe');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableRenderWireframe'] = function(block) {
#
# 	var code = 'enableRenderWireframe()\n';
# return code;};
#
# ----New method----
# enableRenderSolid
# []
# []
# Blockly.Blocks['enableRenderSolid'] = { init: function() { this.appendDummyInput().appendField('enableRenderSolid');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableRenderSolid'] = function(block) {
#
# 	var code = 'enableRenderSolid()\n';
# return code;};
#
# ----New method----
# enableRenderTexture
# []
# []
# Blockly.Blocks['enableRenderTexture'] = { init: function() { this.appendDummyInput().appendField('enableRenderTexture');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableRenderTexture'] = function(block) {
#
# 	var code = 'enableRenderTexture()\n';
# return code;};
#
# ----New method----
# enableRenderShaded
# []
# []
# Blockly.Blocks['enableRenderShaded'] = { init: function() { this.appendDummyInput().appendField('enableRenderShaded');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableRenderShaded'] = function(block) {
#
# 	var code = 'enableRenderShaded()\n';
# return code;};
#
# ----New method----
# moveCamera
# ['x', 'y', 'z', 'rx', 'ry', 'rz']
# ['float', 'float', 'float', 'float', 'float', 'float']
# Blockly.Blocks['moveCamera'] = { init: function() { this.appendDummyInput().appendField('moveCamera');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('rx').setCheck('Number').appendField('rx');
# 	this.appendValueInput('ry').setCheck('Number').appendField('ry');
# 	this.appendValueInput('rz').setCheck('Number').appendField('rz');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['moveCamera'] = function(block) {
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var rx = Blockly.Python.valueToCode(block, 'rx', Blockly.Python.ORDER_ATOMIC);
# 	var ry = Blockly.Python.valueToCode(block, 'ry', Blockly.Python.ORDER_ATOMIC);
# 	var rz = Blockly.Python.valueToCode(block, 'rz', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'moveCamera('+x+','+y+','+z+','+rx+','+ry+','+rz+')\n';
# return code;};
#
# ----New method----
# setCamera
# ['x', 'y', 'z', 'rx', 'ry', 'rz']
# ['float', 'float', 'float', 'float', 'float', 'float']
# Blockly.Blocks['setCamera'] = { init: function() { this.appendDummyInput().appendField('setCamera');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('rx').setCheck('Number').appendField('rx');
# 	this.appendValueInput('ry').setCheck('Number').appendField('ry');
# 	this.appendValueInput('rz').setCheck('Number').appendField('rz');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['setCamera'] = function(block) {
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var rx = Blockly.Python.valueToCode(block, 'rx', Blockly.Python.ORDER_ATOMIC);
# 	var ry = Blockly.Python.valueToCode(block, 'ry', Blockly.Python.ORDER_ATOMIC);
# 	var rz = Blockly.Python.valueToCode(block, 'rz', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'setCamera('+x+','+y+','+z+','+rx+','+ry+','+rz+')\n';
# return code;};
#
# ----New method----
# createAssetSkybox
# ['s1', 's2', 's3', 's4', 's5', 's6']
# ['str', 'str', 'str', 'str', 'str', 'str']
# Blockly.Blocks['createAssetSkybox'] = { init: function() { this.appendDummyInput().appendField('createAssetSkybox');
# 	this.appendValueInput('s1').setCheck('String').appendField('s1');
# 	this.appendValueInput('s2').setCheck('String').appendField('s2');
# 	this.appendValueInput('s3').setCheck('String').appendField('s3');
# 	this.appendValueInput('s4').setCheck('String').appendField('s4');
# 	this.appendValueInput('s5').setCheck('String').appendField('s5');
# ...
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createObject('+name+','+asset+','+x+','+y+','+z+')\n';
# return code;};
# Blockly.Blocks['writeFile'] = { init: function() { this.appendDummyInput().appendField('writeFile');
# 	this.appendValueInput('filename').setCheck('String').appendField('filename');
# 	this.appendValueInput('text').setCheck('String').appendField('text');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['writeFile'] = function(block) {
# 	var filename = Blockly.Python.valueToCode(block, 'filename', Blockly.Python.ORDER_ATOMIC);
# 	var text = Blockly.Python.valueToCode(block, 'text', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'writeFile('+filename+','+text+')\n';
# return code;};
# Blockly.Blocks['openFile'] = { init: function() { this.appendDummyInput().appendField('openFile');
# 	this.appendValueInput('filename').setCheck('String').appendField('filename');
# this.appendDummyInput();this.setOutput(true, 'String');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['openFile'] = function(block) {
# 	var filename = Blockly.Python.valueToCode(block, 'filename', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'openFile('+filename+')';
# return [code, Blockly.Python.ORDER_NONE];};
# Blockly.Blocks['timeSinceStartup'] = { init: function() { this.appendDummyInput().appendField('timeSinceStartup');
# this.setOutput(true, 'Number');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['timeSinceStartup'] = function(block) {
#
# 	var code = 'timeSinceStartup()';
# return [code, Blockly.Python.ORDER_NONE];};
# Blockly.Blocks['getPlatform'] = { init: function() { this.appendDummyInput().appendField('getPlatform');
# this.setOutput(true, 'String');this.setColour(330);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['getPlatform'] = function(block) {
#
# 	var code = 'getPlatform()';
# return [code, Blockly.Python.ORDER_NONE];};
# Blockly.Blocks['enableRenderWireframe'] = { init: function() { this.appendDummyInput().appendField('enableRenderWireframe');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableRenderWireframe'] = function(block) {
#
# 	var code = 'enableRenderWireframe()\n';
# return code;};
# Blockly.Blocks['enableRenderSolid'] = { init: function() { this.appendDummyInput().appendField('enableRenderSolid');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableRenderSolid'] = function(block) {
#
# 	var code = 'enableRenderSolid()\n';
# return code;};
# Blockly.Blocks['enableRenderTexture'] = { init: function() { this.appendDummyInput().appendField('enableRenderTexture');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableRenderTexture'] = function(block) {
#
# 	var code = 'enableRenderTexture()\n';
# return code;};
# Blockly.Blocks['enableRenderShaded'] = { init: function() { this.appendDummyInput().appendField('enableRenderShaded');
# this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['enableRenderShaded'] = function(block) {
#
# 	var code = 'enableRenderShaded()\n';
# return code;};
# Blockly.Blocks['moveCamera'] = { init: function() { this.appendDummyInput().appendField('moveCamera');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('rx').setCheck('Number').appendField('rx');
# 	this.appendValueInput('ry').setCheck('Number').appendField('ry');
# 	this.appendValueInput('rz').setCheck('Number').appendField('rz');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['moveCamera'] = function(block) {
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var rx = Blockly.Python.valueToCode(block, 'rx', Blockly.Python.ORDER_ATOMIC);
# 	var ry = Blockly.Python.valueToCode(block, 'ry', Blockly.Python.ORDER_ATOMIC);
# 	var rz = Blockly.Python.valueToCode(block, 'rz', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'moveCamera('+x+','+y+','+z+','+rx+','+ry+','+rz+')\n';
# return code;};
# Blockly.Blocks['setCamera'] = { init: function() { this.appendDummyInput().appendField('setCamera');
# 	this.appendValueInput('x').setCheck('Number').appendField('x');
# 	this.appendValueInput('y').setCheck('Number').appendField('y');
# 	this.appendValueInput('z').setCheck('Number').appendField('z');
# 	this.appendValueInput('rx').setCheck('Number').appendField('rx');
# 	this.appendValueInput('ry').setCheck('Number').appendField('ry');
# 	this.appendValueInput('rz').setCheck('Number').appendField('rz');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['setCamera'] = function(block) {
# 	var x = Blockly.Python.valueToCode(block, 'x', Blockly.Python.ORDER_ATOMIC);
# 	var y = Blockly.Python.valueToCode(block, 'y', Blockly.Python.ORDER_ATOMIC);
# 	var z = Blockly.Python.valueToCode(block, 'z', Blockly.Python.ORDER_ATOMIC);
# 	var rx = Blockly.Python.valueToCode(block, 'rx', Blockly.Python.ORDER_ATOMIC);
# 	var ry = Blockly.Python.valueToCode(block, 'ry', Blockly.Python.ORDER_ATOMIC);
# 	var rz = Blockly.Python.valueToCode(block, 'rz', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'setCamera('+x+','+y+','+z+','+rx+','+ry+','+rz+')\n';
# return code;};
# Blockly.Blocks['createAssetSkybox'] = { init: function() { this.appendDummyInput().appendField('createAssetSkybox');
# 	this.appendValueInput('s1').setCheck('String').appendField('s1');
# 	this.appendValueInput('s2').setCheck('String').appendField('s2');
# 	this.appendValueInput('s3').setCheck('String').appendField('s3');
# 	this.appendValueInput('s4').setCheck('String').appendField('s4');
# 	this.appendValueInput('s5').setCheck('String').appendField('s5');
# 	this.appendValueInput('s6').setCheck('String').appendField('s6');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetSkybox'] = function(block) {
# 	var s1 = Blockly.Python.valueToCode(block, 's1', Blockly.Python.ORDER_ATOMIC);
# 	var s2 = Blockly.Python.valueToCode(block, 's2', Blockly.Python.ORDER_ATOMIC);
# 	var s3 = Blockly.Python.valueToCode(block, 's3', Blockly.Python.ORDER_ATOMIC);
# 	var s4 = Blockly.Python.valueToCode(block, 's4', Blockly.Python.ORDER_ATOMIC);
# 	var s5 = Blockly.Python.valueToCode(block, 's5', Blockly.Python.ORDER_ATOMIC);
# 	var s6 = Blockly.Python.valueToCode(block, 's6', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetSkybox('+s1+','+s2+','+s3+','+s4+','+s5+','+s6+')\n';
# return code;};
# Blockly.Blocks['createAssetPlane'] = { init: function() { this.appendDummyInput().appendField('createAssetPlane');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetPlane'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetPlane('+name+')\n';
# return code;};
# Blockly.Blocks['createAssetTeapot'] = { init: function() { this.appendDummyInput().appendField('createAssetTeapot');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetTeapot'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetTeapot('+name+')\n';
# return code;};
# Blockly.Blocks['createAssetCone'] = { init: function() { this.appendDummyInput().appendField('createAssetCone');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetCone'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetCone('+name+')\n';
# return code;};
# Blockly.Blocks['createAssetTorus'] = { init: function() { this.appendDummyInput().appendField('createAssetTorus');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetTorus'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetTorus('+name+')\n';
# return code;};
# Blockly.Blocks['createAssetSphere'] = { init: function() { this.appendDummyInput().appendField('createAssetSphere');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetSphere'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetSphere('+name+')\n';
# return code;};
# Blockly.Blocks['createAssetCube'] = { init: function() { this.appendDummyInput().appendField('createAssetCube');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetCube'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetCube('+name+')\n';
# return code;};
# Blockly.Blocks['createAssetModel'] = { init: function() { this.appendDummyInput().appendField('createAssetModel');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('filename').setCheck('String').appendField('filename');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetModel'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var filename = Blockly.Python.valueToCode(block, 'filename', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetModel('+name+','+filename+')\n';
# return code;};
# Blockly.Blocks['createAssetParticle'] = { init: function() { this.appendDummyInput().appendField('createAssetParticle');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('filename').setCheck('String').appendField('filename');
# 	this.appendValueInput('ParticleCount').setCheck('Number').appendField('ParticleCount');
# 	this.appendValueInput('FrameCount').setCheck('Number').appendField('FrameCount');
# 	this.appendValueInput('scaleParticle').setCheck('Number').appendField('scaleParticle');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetParticle'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var filename = Blockly.Python.valueToCode(block, 'filename', Blockly.Python.ORDER_ATOMIC);
# 	var ParticleCount = Blockly.Python.valueToCode(block, 'ParticleCount', Blockly.Python.ORDER_ATOMIC);
# 	var FrameCount = Blockly.Python.valueToCode(block, 'FrameCount', Blockly.Python.ORDER_ATOMIC);
# 	var scaleParticle = Blockly.Python.valueToCode(block, 'scaleParticle', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetParticle('+name+','+filename+','+ParticleCount+','+FrameCount+','+scaleParticle+')\n';
# return code;};
# Blockly.Blocks['createAssetTexture'] = { init: function() { this.appendDummyInput().appendField('createAssetTexture');
# 	this.appendValueInput('name').setCheck('String').appendField('name');
# 	this.appendValueInput('filename').setCheck('String').appendField('filename');
# this.appendDummyInput();this.setPreviousStatement(true, null);this.setNextStatement(true, null);this.setColour(230);this.setTooltip('');this.setHelpUrl('');}};
#
# Blockly.Python['createAssetTexture'] = function(block) {
# 	var name = Blockly.Python.valueToCode(block, 'name', Blockly.Python.ORDER_ATOMIC);
# 	var filename = Blockly.Python.valueToCode(block, 'filename', Blockly.Python.ORDER_ATOMIC);
#
# 	var code = 'createAssetTexture('+name+','+filename+')\n';
# return code;};
#
#
#
# BLOCKLY XML:
#
#
#
# 	<block type="timeSinceFrameMs"></block>
# 	<block type="isButtonRight"></block>
# 	<block type="isButtonLeft"></block>
# 	<block type="isButtonDown"></block>
# 	<block type="isButtonUp"></block>
# 	<block type="isButtonY"></block>
# 	<block type="isButtonX"></block>
# 	<block type="isButtonB"></block>
# 	<block type="isButtonA"></block>
# 	<block type="enableObject"></block>
# 	<block type="disableObject"></block>
# 	<block type="createLog"></block>
# 	<block type="cleanLog"></block>
# 	<block type="createText"></block>
# 	<block type="updateSprite"></block>
# 	<block type="moveSprite"></block>
# 	<block type="setSprite"></block>
# 	<block type="deleteObject"></block>
# 	<block type="deleteSpritefontText"></block>
# 	<block type="createSpritefontText"></block>
# 	<block type="createSpriteWithCoords"></block>
# 	<block type="createSpriteWithColor"></block>
# 	<block type="createSprite"></block>
# 	<block type="getObjectSZ"></block>
# 	<block type="getObjectSY"></block>
# 	<block type="getObjectSX"></block>
# 	<block type="getObjectRZ"></block>
# 	<block type="getObjectRY"></block>
# 	<block type="getObjectRX"></block>
# 	<block type="getObjectPZ"></block>
# 	<block type="getObjectPY"></block>
# 	<block type="getObjectPX"></block>
# 	<block type="setObjectwithRotationScale"></block>
# 	<block type="moveObjectwithRotationScale"></block>
# 	<block type="setObject"></block>
# 	<block type="createObjectwithRotationScale"></block>
# 	<block type="createObjectwithScale"></block>
# 	<block type="createObjectwithRotation"></block>
# 	<block type="createObject"></block>
# 	<block type="writeFile"></block>
# 	<block type="openFile"></block>
# 	<block type="timeSinceStartup"></block>
# 	<block type="getPlatform"></block>
# 	<block type="enableRenderWireframe"></block>
# 	<block type="enableRenderSolid"></block>
# 	<block type="enableRenderTexture"></block>
# 	<block type="enableRenderShaded"></block>
# 	<block type="moveCamera"></block>
# 	<block type="setCamera"></block>
# 	<block type="createAssetSkybox"></block>
# 	<block type="createAssetPlane"></block>
# 	<block type="createAssetTeapot"></block>
# 	<block type="createAssetCone"></block>
# 	<block type="createAssetTorus"></block>
# 	<block type="createAssetSphere"></block>
# 	<block type="createAssetCube"></block>
# 	<block type="createAssetModel"></block>
# 	<block type="createAssetParticle"></block>
# 	<block type="createAssetTexture"></block>
