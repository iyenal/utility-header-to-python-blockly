# %%
# Gen7 Engine Python3 utility to convert a C/C++ header to a Python comprehensible form
    
import re

# initializing string

txt = open("utilities/header-list.h", "r").read()

txt = txt.replace("}", "} ;")
txt = txt.replace("//{", "")
txt = txt.replace("){", " ) ")
txt = re.sub('{[^}]+}', '', txt)
txt = txt.replace("(", " ")
txt = txt.replace(")", " ")
txt = txt.replace(",", " ")
txt = txt.replace("char *", "str ")
txt = txt.replace("char*", "str")
txt = txt.replace("static ", "")

    
# printing original string 
print ("-----------The original signature : \n" +  txt) 
    
# using split() 
# to extract words from string 
res = txt.split()

function_name = ""
function_param = []
function_types = []

_fname = 0
_ftype = 0
_fparam = 0

output = ""

def reset_code_line():
    global function_name
    global function_param
    global function_types
    
    function_name = ""
    function_param = []
    function_types = []
    _fname = 0
    _ftype = 0
    _fparam = 0

def generate_code_line():
    global output
    global function_name
    global function_param
    global function_types
    
    print(function_name)
    print(function_param)
    print(function_types)

    
    # def createObjectwithRotation(x: float, y: float, z: float, rotX: float, rotY: float, rotZ: float, type: int, name: str, asset) -> None:
    code_line = "def "+function_name+"("
    
    for i in range(0, len(function_param)):
        #print(i)
        code_line = code_line+function_param[i]+": "+function_types[i]+", "
    
    code_line=code_line+"):\n"
    code_line=code_line.replace(", )",")")
    code_line=code_line+"\tpass\n"
    print(code_line)
    output = output + code_line
    
    
# printing result 
print ("\n---------The words :")

for i in res:
    
    #print(i)
    
    # Reset new method
    if(i == ";"):
        print("----New method")
        generate_code_line()
        _fname = 0
        continue
        
    # Get function signature type
    if(_fname == 0):
        _fname = 1
        continue
    # Get function signature name
    if(_fname == 1):
        function_name = i
        _fname = 2
        continue
        
    # Get function param type
    if(_ftype == 0):
        function_types.append(i)
        _ftype = 1
        _fparam = 1
        continue
        
    # Get function param name
    if(_fparam == 1):
        function_param.append(i)
        _ftype = 0
        _fparam = 0
        continue
    
    
print("--------------------- EXPORTED ---------------------")
print("\n")
print(output)
# Out:
# -----------The original signature :
# str getPlatform     brrrrrr} ;
# bool isButtonRight  ;
# bool isButtonLeft  ;
# bool isButtonDown  ;
# bool isButtonUp  ;
# bool isButtonY  ;
# bool isButtonX  ;
# bool isButtonB  ;
# bool isButtonA  ;
# void initControls  ;
# void createLog str text ;
# void deleteObject str name ;
# void cleanLog  ;
# void createText int xpos int ypos int r int g int b float fontsize str text ;
# void updateSprite str name str asset ;
# void moveSprite str name float x float y int layer ;
# void setSprite str name float x float y float sizeX float sizeY int layer ;
# void createSpritefontText int xpos int ypos int fontsize float condens int lines int columns str text str fontface str spritefont ;
# void createSpriteWithCoords str name str asset float x float y float sizeX float sizeY float t0 float t1 float t2 float t3 int layer ;
# void createSpriteWithColor str name str asset float x float y float sizeX float sizeY int r int g int b int layer ;
# void createSprite str name str asset float x float y float sizeX float sizeY int layer ;
# void setObjectwithRotationScale str name float x float y float z float rotX float rotY float rotZ float scX float scY float scZ ;
# void moveObjectwithRotationScale str name float x float y float z float rotX float rotY float rotZ float scX float scY float scZ ;
# void setObject str name float x float y float z ;
# void createObjectwithRotationScale str name str asset float x float y float z float rotX float rotY float rotZ float scX float scY float scZ int type ;
# void createObjectwithScale str name str asset float x float y float z float scX float scY float scZ int type ;
# void createObjectwithRotation str name str asset float x float y float z float rotX float rotY float rotZ int type ;
# void createObject str name str asset float x float y float z int type ;
# void enableRenderWireframe  ;
# void enableRenderSolid  ;
# void enableRenderTexture  ;
# void enableRenderShaded  ;
# void moveCamera float x float y float z float rx float ry float rz ;
# void setCamera float x float y float z float rx float ry float rz ;
# void createAssetSkybox str s1 str s2 str s3 str s4 str s5 str s6 ;
# void createAssetPlane str name ;
# void createAssetTeapot str name ;
# void createAssetCone str name ;
# void createAssetTorus str name ;
# void createAssetSphere str name ;
# void createAssetCube str name ;
# void createAssetModel str name str filename ;
# void createAssetParticle str name str filename int ParticleCount int FrameCount float scaleParticle ;
# void createAssetTexture str name str filename ;
#
#
# ---------The words :
# ----New method
# getPlatform
# []
# ['brrrrrr}']
# def getPlatform():
# 	pass
#
# ----New method
# isButtonRight
# []
# []
# def isButtonRight():
# 	pass
#
# ----New method
# isButtonLeft
# []
# []
# def isButtonLeft():
# 	pass
#
# ----New method
# isButtonDown
# []
# []
# def isButtonDown():
# 	pass
#
# ----New method
# isButtonUp
# []
# []
# def isButtonUp():
# 	pass
#
# ----New method
# isButtonY
# []
# []
# def isButtonY():
# 	pass
#
# ----New method
# isButtonX
# []
# []
# def isButtonX():
# 	pass
#
# ----New method
# isButtonB
# []
# []
# def isButtonB():
# 	pass
#
# ----New method
# isButtonA
# []
# []
# def isButtonA():
# 	pass
#
# ----New method
# initControls
# []
# []
# def initControls():
# 	pass
#
# ----New method
# createLog
# ['str']
# ['text']
# def createLog(str: text):
# 	pass
#
# ----New method
# deleteObject
# ['str']
# ['name']
# def deleteObject(str: name):
# 	pass
#
# ----New method
# cleanLog
# []
# []
# def cleanLog():
# 	pass
#
# ----New method
# createText
# ['int', 'int', 'int', 'int', 'int', 'float', 'str']
# ['xpos', 'ypos', 'r', 'g', 'b', 'fontsize', 'text']
# def createText(int: xpos, int: ypos, int: r, int: g, int: b, float: fontsize, str: text):
# 	pass
#
# ----New method
# updateSprite
# ['str', 'str']
# ['name', 'asset']
# def updateSprite(str: name, str: asset):
# 	pass
#
# ----New method
# moveSprite
# ['str', 'float', 'float', 'int']
# ['name', 'x', 'y', 'layer']
# def moveSprite(str: name, float: x, float: y, int: layer):
# 	pass
#
# ----New method
# setSprite
# ['str', 'float', 'float', 'float', 'float', 'int']
# ['name', 'x', 'y', 'sizeX', 'sizeY', 'layer']
# def setSprite(str: name, float: x, float: y, float: sizeX, float: sizeY, int: layer):
# 	pass
#
# ----New method
# createSpritefontText
# ['int', 'int', 'int', 'float', 'int', 'int', 'str', 'str', 'str']
# ['xpos', 'ypos', 'fontsize', 'condens', 'lines', 'columns', 'text', 'fontface', 'spritefont']
# def createSpritefontText(int: xpos, int: ypos, int: fontsize, float: condens, int: lines, int: columns, str: text, str: fontface, str: spritefont):
# 	pass
#
# ----New method
# createSpriteWithCoords
# ['str', 'str', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'int']
# ['name', 'asset', 'x', 'y', 'sizeX', 'sizeY', 't0', 't1', 't2', 't3', 'layer']
# def createSpriteWithCoords(str: name, str: asset, float: x, float: y, float: sizeX, float: sizeY, float: t0, float: t1, float: t2, float: t3, int: layer):
# 	pass
#
# ----New method
# createSpriteWithColor
# ['str', 'str', 'float', 'float', 'float', 'float', 'int', 'int', 'int', 'int']
# ['name', 'asset', 'x', 'y', 'sizeX', 'sizeY', 'r', 'g', 'b', 'layer']
# def createSpriteWithColor(str: name, str: asset, float: x, float: y, float: sizeX, float: sizeY, int: r, int: g, int: b, int: layer):
# 	pass
#
# ----New method
# createSprite
# ['str', 'str', 'float', 'float', 'float', 'float', 'int']
# ['name', 'asset', 'x', 'y', 'sizeX', 'sizeY', 'layer']
# def createSprite(str: name, str: asset, float: x, float: y, float: sizeX, float: sizeY, int: layer):
# 	pass
#
# ----New method
# setObjectwithRotationScale
# ['str', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float']
# ['name', 'x', 'y', 'z', 'rotX', 'rotY', 'rotZ', 'scX', 'scY', 'scZ']
# def setObjectwithRotationScale(str: name, float: x, float: y, float: z, float: rotX, float: rotY, float: rotZ, float: scX, float: scY, float: scZ):
# 	pass
#
# ----New method
# moveObjectwithRotationScale
# ['str', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float']
# ['name', 'x', 'y', 'z', 'rotX', 'rotY', 'rotZ', 'scX', 'scY', 'scZ']
# def moveObjectwithRotationScale(str: name, float: x, float: y, float: z, float: rotX, float: rotY, float: rotZ, float: scX, float: scY, float: scZ):
# 	pass
#
# ----New method
# setObject
# ['str', 'float', 'float', 'float']
# ['name', 'x', 'y', 'z']
# def setObject(str: name, float: x, float: y, float: z):
# 	pass
#
# ----New method
# createObjectwithRotationScale
# ['str', 'str', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'int']
# ['name', 'asset', 'x', 'y', 'z', 'rotX', 'rotY', 'rotZ', 'scX', 'scY', 'scZ', 'type']
# def createObjectwithRotationScale(str: name, str: asset, float: x, float: y, float: z, float: rotX, float: rotY, float: rotZ, float: scX, float: scY, float: scZ, int: type):
# 	pass
#
# ----New method
# createObjectwithScale
# ['str', 'str', 'float', 'float', 'float', 'float', 'float', 'float', 'int']
# ['name', 'asset', 'x', 'y', 'z', 'scX', 'scY', 'scZ', 'type']
# def createObjectwithScale(str: name, str: asset, float: x, float: y, float: z, float: scX, float: scY, float: scZ, int: type):
# 	pass
#
# ----New method
# createObjectwithRotation
# ['str', 'str', 'float', 'float', 'float', 'float', 'float', 'float', 'int']
# ['name', 'asset', 'x', 'y', 'z', 'rotX', 'rotY', 'rotZ', 'type']
# def createObjectwithRotation(str: name, str: asset, float: x, float: y, float: z, float: rotX, float: rotY, float: rotZ, int: type):
# 	pass
#
# ----New method
# createObject
# ['str', 'str', 'float', 'float', 'float', 'int']
# ['name', 'asset', 'x', 'y', 'z', 'type']
# def createObject(str: name, str: asset, float: x, float: y, float: z, int: type):
# 	pass
#
# ----New method
# enableRenderWireframe
# []
# []
# def enableRenderWireframe():
# 	pass
#
# ----New method
# enableRenderSolid
# []
# []
# def enableRenderSolid():
# 	pass
#
# ----New method
# enableRenderTexture
# []
# []
# def enableRenderTexture():
# 	pass
#
# ----New method
# enableRenderShaded
# []
# []
# def enableRenderShaded():
# 	pass
#
# ----New method
# moveCamera
# ['float', 'float', 'float', 'float', 'float', 'float']
# ['x', 'y', 'z', 'rx', 'ry', 'rz']
# def moveCamera(float: x, float: y, float: z, float: rx, float: ry, float: rz):
# 	pass
#
# ----New method
# setCamera
# ['float', 'float', 'float', 'float', 'float', 'float']
# ['x', 'y', 'z', 'rx', 'ry', 'rz']
# def setCamera(float: x, float: y, float: z, float: rx, float: ry, float: rz):
# 	pass
#
# ----New method
# createAssetSkybox
# ['str', 'str', 'str', 'str', 'str', 'str']
# ['s1', 's2', 's3', 's4', 's5', 's6']
# def createAssetSkybox(str: s1, str: s2, str: s3, str: s4, str: s5, str: s6):
# 	pass
#
# ----New method
# createAssetPlane
# ['str']
# ['name']
# def createAssetPlane(str: name):
# 	pass
#
# ----New method
# createAssetTeapot
# ['str']
# ['name']
# def createAssetTeapot(str: name):
# 	pass
#
# ----New method
# createAssetCone
# ['str']
# ['name']
# def createAssetCone(str: name):
# 	pass
#
# ----New method
# createAssetTorus
# ['str']
# ['name']
# def createAssetTorus(str: name):
# 	pass
#
# ----New method
# createAssetSphere
# ['str']
# ['name']
# def createAssetSphere(str: name):
# 	pass
#
# ----New method
# createAssetCube
# ['str']
# ['name']
# def createAssetCube(str: name):
# 	pass
#
# ----New method
# createAssetModel
# ['str', 'str']
# ['name', 'filename']
# def createAssetModel(str: name, str: filename):
# 	pass
#
# ----New method
# createAssetParticle
# ['str', 'str', 'int', 'int', 'float']
# ['name', 'filename', 'ParticleCount', 'FrameCount', 'scaleParticle']
# def createAssetParticle(str: name, str: filename, int: ParticleCount, int: FrameCount, float: scaleParticle):
# 	pass
#
# ----New method
# createAssetTexture
# ['str', 'str']
# ['name', 'filename']
# def createAssetTexture(str: name, str: filename):
# 	pass
#
# --------------------- EXPORTED ---------------------
#
#
# def getPlatform():
# 	pass
# def isButtonRight():
# 	pass
# def isButtonLeft():
# 	pass
# def isButtonDown():
# 	pass
# def isButtonUp():
# 	pass
# def isButtonY():
# 	pass
# def isButtonX():
# 	pass
# def isButtonB():
# 	pass
# def isButtonA():
# 	pass
# def initControls():
# 	pass
# def createLog(str: text):
# 	pass
# def deleteObject(str: name):
# 	pass
# def cleanLog():
# 	pass
# def createText(int: xpos, int: ypos, int: r, int: g, int: b, float: fontsize, str: text):
# 	pass
# def updateSprite(str: name, str: asset):
# 	pass
# def moveSprite(str: name, float: x, float: y, int: layer):
# 	pass
# def setSprite(str: name, float: x, float: y, float: sizeX, float: sizeY, int: layer):
# 	pass
# def createSpritefontText(int: xpos, int: ypos, int: fontsize, float: condens, int: lines, int: columns, str: text, str: fontface, str: spritefont):
# 	pass
# def createSpriteWithCoords(str: name, str: asset, float: x, float: y, float: sizeX, float: sizeY, float: t0, float: t1, float: t2, float: t3, int: layer):
# 	pass
# def createSpriteWithColor(str: name, str: asset, float: x, float: y, float: sizeX, float: sizeY, int: r, int: g, int: b, int: layer):
# 	pass
# def createSprite(str: name, str: asset, float: x, float: y, float: sizeX, float: sizeY, int: layer):
# 	pass
# def setObjectwithRotationScale(str: name, float: x, float: y, float: z, float: rotX, float: rotY, float: rotZ, float: scX, float: scY, float: scZ):
# 	pass
# def moveObjectwithRotationScale(str: name, float: x, float: y, float: z, float: rotX, float: rotY, float: rotZ, float: scX, float: scY, float: scZ):
# 	pass
# def setObject(str: name, float: x, float: y, float: z):
# 	pass
# def createObjectwithRotationScale(str: name, str: asset, float: x, float: y, float: z, float: rotX, float: rotY, float: rotZ, float: scX, float: scY, float: scZ, int: type):
# 	pass
# def createObjectwithScale(str: name, str: asset, float: x, float: y, float: z, float: scX, float: scY, float: scZ, int: type):
# 	pass
# def createObjectwithRotation(str: name, str: asset, float: x, float: y, float: z, float: rotX, float: rotY, float: rotZ, int: type):
# 	pass
# def createObject(str: name, str: asset, float: x, float: y, float: z, int: type):
# 	pass
# def enableRenderWireframe():
# 	pass
# def enableRenderSolid():
# 	pass
# def enableRenderTexture():
# 	pass
# def enableRenderShaded():
# 	pass
# def moveCamera(float: x, float: y, float: z, float: rx, float: ry, float: rz):
# 	pass
# def setCamera(float: x, float: y, float: z, float: rx, float: ry, float: rz):
# 	pass
# def createAssetSkybox(str: s1, str: s2, str: s3, str: s4, str: s5, str: s6):
# 	pass
# def createAssetPlane(str: name):
# 	pass
# def createAssetTeapot(str: name):
# 	pass
# def createAssetCone(str: name):
# 	pass
# def createAssetTorus(str: name):
# 	pass
# def createAssetSphere(str: name):
# 	pass
# def createAssetCube(str: name):
# 	pass
# def createAssetModel(str: name, str: filename):
# 	pass
# def createAssetParticle(str: name, str: filename, int: ParticleCount, int: FrameCount, float: scaleParticle):
# 	pass
# def createAssetTexture(str: name, str: filename):
# 	pass
